# %%
import numpy as np
import matplotlib.pyplot as plt

from skimage.data import shepp_logan_phantom
from skimage.transform import iradon, radon, rescale

# %% [markdown]
# Reference code

# %%
I = shepp_logan_phantom()
p_angles = np.linspace(0., 180., 256, endpoint=False)
I_p = radon(I, theta=p_angles)
I_r = iradon(I_p, theta=p_angles, circle=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4.5))

ax1.set_title("Original")
ax1.imshow(I, cmap=plt.cm.Greys_r)

dx, dy = 0.5 * 180.0 / max(I.shape), 0.5 / I_p.shape[0]
ax2.set_title("Radon transform\n(Sinogram)")
ax2.set_xlabel("Projection angle (deg)")
ax2.set_ylabel("Projection position (pixels)")
ax2.imshow(I_p, cmap=plt.cm.Greys_r,
           extent=(-dx, 180.0 + dx, -dy, I_p.shape[0] + dy),
           aspect='auto')

fig.tight_layout()
plt.show()

# %%
import result_claude_try1

I_claude = result_claude_try1.recon( I_p, p_angles )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> import result_claude_try1
# ----> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> I_claude = result_claude_try1.recon( I_p, p_angles )
#
# File ~/Documents/Local Data/github/LLM_Backprojection_Testing/result_claude_try1.py:25, in recon(I_p, p_angles)
#      23 # Apply filter to sinogram
#      24 I_f = np.fft.fft(I_p, axis=0)
# ---> 25 I_f = np.multiply(I_f, ramp_filter)
#      26 I_f = np.real(np.fft.ifft(I_f, axis=0))
# ...

# %%
import result_claude_try2

I_claude = result_claude_try2.recon( I_p, p_angles )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> import result_claude_try2
# ----> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> I_claude = result_claude_try2.recon( I_p, p_angles )
#
# File ~/Documents/Local Data/github/LLM_Backprojection_Testing/result_claude_try2.py:23, in recon(I_p, p_angles)
#      21     proj = I_f[:,i]
#      22     indices = np.round(N/2 + proj * np.cos(angle)).astype(int)
# ---> 23     recon_img[indices, np.arange(N)] += proj * np.sin(angle)
# ...

# %%
import result_claude_try3

I_claude = result_claude_try3.recon( I_p, p_angles )

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(8, 4.5))

ax1.set_title("Original")
ax1.imshow(I, cmap=plt.cm.Greys_r)

ax2.set_title("iradon")
ax2.imshow(I_r, cmap=plt.cm.Greys_r)

ax3.set_title("Claude")
ax3.imshow(I_claude, cmap=plt.cm.Greys_r)

fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> ax2.imshow(I_r, cmap=plt.cm.Greys_r)
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> ax3.set_title("Claude")
# ---> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> ax3.imshow(I_claude, cmap=plt.cm.Greys_r)
# ...

# %%
import result_bard_try1

I_claude = result_bard_try1.recon( I_p, p_angles )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import result_bard_try1
# ----> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> I_claude = result_bard_try1.recon( I_p, p_angles )
#
# File ~/Documents/Local Data/github/LLM_Backprojection_Testing/result_bard_try1.py:20, in recon(I_p, p_angles)
#      17 ramp_filter = np.arange(I_p.shape[0])
#      19 # Calculate the filtered projections.
# ---> 20 filtered_projections = I_p * ramp_filter
#      22 # Backproject the filtered projections.
# ...

# %%
import result_bard_try2

I_claude = result_bard_try2.recon( I_p, p_angles )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import result_bard_try2
# ----> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> I_claude = result_bard_try2.recon( I_p, p_angles )
#
# File ~/Documents/Local Data/github/LLM_Backprojection_Testing/result_bard_try2.py:28, in recon(I_p, p_angles)
#      26 reconstructed_image = np.zeros(I_p.shape[1])
#      27 for i in range(I_p.shape[1]):
# ---> 28   reconstructed_image += filtered_projections[:, i] * np.cos(p_angles - i)
# ...

# %%
import result_bard_try3

I_claude = result_bard_try3.recon( I_p, p_angles )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/axm3/Documents/Local Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> import result_bard_try3
#       <a href='vscode-notebook-cell:/Users/axm3/Documents/Local%20Data/github/LLM_Backprojection_Testing/LLM_Backprojection_Testing.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> I_claude = result_bard_try3.recon( I_p, p_angles )
#
# File ~/Documents/Local Data/github/LLM_Backprojection_Testing/result_bard_try3.py:40
#      37 p_angles = np.random.rand(400)
#      39 # Reconstruct the image.
# ---> 40 reconstructed_image = recon(I_p, p_angles)
#
# ...
